# %% [markdown]
# # Classification Tutorial

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler

# %%
data = load_breast_cancer(return_X_y=False, as_frame=True).frame

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=False)

# %%
split = StratifiedShuffleSplit(test_size=0.2, n_splits=1)

for trainIdx, testIdx in split.split(X, y):
    X_train, X_test = X[trainIdx], X[testIdx]
    y_train, Xytest = y[trainIdx], y[testIdx]

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
